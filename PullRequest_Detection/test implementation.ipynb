# %% [markdown]
# # Test Implementation
#
# John Giannini
#
# 27 September 2022
#
#
# This code will test our similarity measurements on our dataset. For each PR that is a duplicate, it will rank other PRs in the same project by similarity and then record the position of the actual duplicate in that ranking in a new attribute, Match_Rank.
#
# The resultant data is outputted as a CSV and an XLSX. (This latter is for easy viewing, as Excel loads parts of the CSV incorectly.)

# %% [markdown]
# 1. [Implementation](#1)
# 2. [Testing Alternate Implementations](#2)

# %% [markdown]
# <h3>Implementation</h3> <a name="2"></a>

# %%
# Mount drive
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/SEDS')

# Import libraries
import pandas as pd
import numpy as np

# Import our code
import code_change_similarity
import file_path_similarity

# Importing Dataset
dataset = pd.read_csv("/content/drive/MyDrive/SEDS/PullRequeset_cleaned.csv")

dataset.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#              Project  Pull_id  \
# 0  joomla/joomla-cms   6660.0
# 1  joomla/joomla-cms   3088.0
# 2  joomla/joomla-cms   3093.0
# 3  joomla/joomla-cms   5664.0
# 4  joomla/joomla-cms   2596.0
#
#                                                Title  \
# 0  Undefined $model variable for postDeleteHook()...
# 1                 [#33256] downloaded vcard is empty
# 2                Bind Variable Fix Within PDO Driver
# 3               CAPTCHA and reCAPTCHA (Legacy) #5595
# 4                   Fix a failing unit test [#32813]
#
#                                              Content  \
# 0  $model is undefined at line 140 for $this->pos...
# 1  http://joomlacode.org/gf/project/joomla/tracke...
# 2  This fix is to revert back to original behavio...
# 3  We were wrong to call it nocaptcha. We were to...
# 4  This should fix a unit test that is currently ...
#
#                                                Files  \
# 0              libraries/legacy/controller/admin.php
# 1  components/com_contact/views/contact/view.vcf.php
# 2           libraries/joomla/database/driver/pdo.php
# 3  administrator/language/en-GB/en-GB.com_config....
# 4  tests/unit/suites/libraries/joomla/registry/fo...
#
#                                            Diff_info  \
# 0  https://github.com/joomla/joomla-cms/pull/6660...
# 1  https://github.com/joomla/joomla-cms/pull/3088...
# 2  https://github.com/joomla/joomla-cms/pull/3093...
# 3  https://github.com/joomla/joomla-cms/pull/5664...
# 4  https://github.com/joomla/joomla-cms/pull/2596...
#
#                                         Diff_content  Label  Duplicates
# 0  diff --git a/libraries/legacy/controller/admin...    1.0      7097.0
# 1  diff --git a/components/com_contact/views/cont...    1.0      3114.0
# 2  diff --git a/libraries/joomla/database/driver/...    1.0      3432.0
# 3  diff --git a/administrator/language/en-GB/en-G...    1.0      5888.0
# 4  diff --git a/tests/unit/suites/libraries/jooml...    1.0      2612.0

# %%
def combined_sim(a, b, data):
  # returns the overall similarity of rows a and b as a number between 0 and 1
  
  # file path similarity
  a_files = data.loc[a, 'Files']
  b_files = data.loc[b, 'Files']
  # make sure that these are strings (our dataset has a few blanks)
  if isinstance(a_files, str) and isinstance(b_files, str):
    file_path_sim = file_path_similarity.check_path_sim(a_files, b_files)
  else:
    # count a lack of listed files as 0 similarity
    file_path_sim = 0

  # deleted line similarity
  lista = code_change_similarity.find_del_lines(dataset.loc[a, 'Diff_content'])
  listb = code_change_similarity.find_del_lines(dataset.loc[b, 'Diff_content'])
  del_sim = code_change_similarity.del_sim(lista, listb)

  # weigh provided values
  combined = (file_path_sim + del_sim)/2
  # print(f'comp. {a} to {b}:\n\tfile_path_sim: {file_path_sim}\n\tdel_sim: {del_sim}\n\tcombined: {combined}') # for debugging
  return combined

def rank_matches(a, data):
  # Compares row a in data to other rows from the same project ranking similarity.
  # If a duplicates some other row, returns the place of that row in the ranking. If not returns NaN.

  # Loop through each row. Take measurements for other rows from same project
  similarities = []
  project = data.loc[a, 'Project']
  for b in range(data.shape[0]):
    # Only process rows in the same project besides row a
    if (not a == b) and (project == data.loc[b, 'Project']):
      # Stores a tuple to similarities: (row, degree of similarity)
      similarities.append( (b, combined_sim(a, b, data)) )
  
  # Sort the produced list of tuples
  similarities.sort(key = lambda x: x[1], reverse=True)
  
  # Find rank of matching entry in list
  id = data.loc[a, 'Pull_id']
  for i in range(len(similarities)):
    if id == data.loc[similarities[i][0], 'Duplicates']:
      # print(f'{a} matches {similarities[i][0]} in possition {i}') # for debugging
      return i
  
  # No match found in similarities list
  return np.nan

# %%
processed_dataset = dataset.copy()
processed_dataset.insert(9, 'Match_Rank', np.nan)

for n in range(processed_dataset.shape[0]):
  # Only process rows if it has a duplicate (otherwise the search is a waste)
  if not processed_dataset.loc[n, 'Duplicates'] == 0:
    print(f'processing row {n}')
    # Stores the match rank to Match_Rank
    processed_dataset.loc[n, 'Match_Rank'] = rank_matches(n, processed_dataset)

processed_dataset.to_csv('/content/drive/MyDrive/SEDS/PullRequeset_processed.csv',index_label=False,index=False)
processed_dataset.to_excel('/content/drive/MyDrive/SEDS/PullRequeset_processed.xlsx')
# Out:
# processing row 0
# processing row 1
# processing row 2
# processing row 3
# processing row 4
# processing row 5
# processing row 6
# processing row 7
# processing row 8
# processing row 9
# processing row 10
# processing row 11
# processing row 12
# processing row 13
# processing row 14
# processing row 15
# processing row 16
# processing row 17
# processing row 18
# processing row 19
# processing row 20
# processing row 21
# processing row 22
# processing row 23
# processing row 24
# processing row 25
# processing row 26
# processing row 27
# processing row 28
# processing row 29
# processing row 30
# processing row 31
# processing row 32
# processing row 33
# processing row 34
# processing row 35
# processing row 36
# processing row 37
# processing row 38
# processing row 39
# processing row 40
# processing row 41
# processing row 42
# processing row 43
# processing row 44
# processing row 45
# processing row 46
# processing row 47
# processing row 48
# processing row 49
# processing row 50
# processing row 51
# processing row 52
# processing row 53
# processing row 54
# processing row 55
# processing row 56
# processing row 57
# processing row 58
# processing row 59
# processing row 60
# processing row 61
# processing row 62
# processing row 63
# processing row 64
# processing row 65
# processing row 66
# processing row 67
# processing row 68
# processing row 69
# processing row 70
# processing row 71
# processing row 72
# processing row 73
# processing row 74
# processing row 75
# processing row 76
# processing row 77
# processing row 78
# processing row 79
# processing row 80
# processing row 81
# processing row 82
# processing row 83
# processing row 84
# processing row 85
# processing row 86
# processing row 174
# processing row 175
# processing row 176
# processing row 177
# processing row 178
# processing row 179
# processing row 180
# processing row 181
# processing row 182
# processing row 183
# processing row 184
# processing row 185
# processing row 186
# processing row 187
# processing row 188
# processing row 189
# processing row 190
# processing row 191
# processing row 192
# processing row 193
# processing row 194
# processing row 195
# processing row 196
# processing row 197
# processing row 198
# processing row 199
# processing row 200
# processing row 201
# processing row 202
# processing row 203
# processing row 204
# processing row 205
# processing row 206
# processing row 207
# processing row 208
# processing row 209
# processing row 210
# processing row 211
# processing row 212
# processing row 213
# processing row 214
# processing row 215
# processing row 216
# processing row 217
# processing row 218
# processing row 219
# processing row 220
# processing row 221
# processing row 222
# processing row 223
# processing row 224
# processing row 225
# processing row 226
# processing row 227
# processing row 228
# processing row 229
# processing row 230
# processing row 231
# processing row 232
# processing row 233
# processing row 234
# processing row 235
# processing row 236
# processing row 237
# processing row 238
# processing row 239
# processing row 240
# processing row 241
# processing row 242
# processing row 243
# processing row 244
# processing row 245
# processing row 246
# processing row 247
# processing row 248
# processing row 324
# processing row 325
# processing row 326
# processing row 327
# processing row 328
# processing row 329
# processing row 330
# processing row 331
# processing row 332
# processing row 333
# processing row 334
# processing row 335
# processing row 336
# processing row 337
# processing row 338
# processing row 339
# processing row 340
# processing row 341
# processing row 342
# processing row 343
# processing row 344
# processing row 345
# processing row 346
# processing row 347
# processing row 348
# processing row 349
# processing row 350
# processing row 351
# processing row 352
# processing row 353
# processing row 354
# processing row 355
# processing row 356
# processing row 357
# processing row 358
# processing row 359
# processing row 360
# processing row 361
# processing row 362
# processing row 363
# processing row 364
# processing row 365
# processing row 366
# processing row 367
# processing row 368
# processing row 369
# processing row 370
# processing row 371
# processing row 372
# processing row 373
# processing row 374
# processing row 375
# processing row 376
# processing row 377
# processing row 378
# processing row 379
# processing row 380
# processing row 381
# processing row 382
# processing row 383
# processing row 384
# processing row 385
# processing row 386
# processing row 387
# processing row 388
# processing row 389
# processing row 390
# processing row 391
# processing row 392
# processing row 393
# processing row 394
# processing row 395
# processing row 396
# processing row 397
# processing row 398
# processing row 399
# processing row 400
# processing row 401
# processing row 402
# processing row 403
# processing row 404
# processing row 405
# processing row 406
# processing row 407
# processing row 408
# processing row 409
# processing row 410
# processing row 411
# processing row 500
# processing row 501
# processing row 502
# processing row 503
# processing row 504
# processing row 505
# processing row 506
# processing row 507
# processing row 508
# processing row 509
# processing row 510
# processing row 511
# processing row 512
# processing row 513
# processing row 514
# processing row 515
# processing row 516
# processing row 517
# processing row 518
# processing row 519
# processing row 520
# processing row 521
# processing row 522
# processing row 523
# processing row 524
# processing row 525
# processing row 526
# processing row 527
# processing row 528
# processing row 529
# processing row 530
# processing row 531
# processing row 532
# processing row 533
# processing row 534
# processing row 535
# processing row 536
# processing row 537
# processing row 538
# processing row 539
# processing row 540
# processing row 582
# processing row 583
# processing row 584
# processing row 585
# processing row 586
# processing row 587
# processing row 588
# processing row 589
# processing row 590
# processing row 591
# processing row 592
# processing row 593
# processing row 594
# processing row 595
# processing row 596
# processing row 597
# processing row 598
# processing row 599
# processing row 600
# processing row 601
# processing row 602
# processing row 603
# processing row 604
# processing row 605
# processing row 630
# processing row 631
# processing row 632
# processing row 633
# processing row 634
# processing row 635
# processing row 636
# processing row 637
# processing row 638
# processing row 639
# processing row 640
# processing row 641
# processing row 642
# processing row 643
# processing row 644
# processing row 645
# processing row 646
# processing row 647
# processing row 648
# processing row 649
# processing row 650
# processing row 651
# processing row 652
# processing row 676
# processing row 677
# processing row 678
# processing row 679
# processing row 680
# processing row 681
# processing row 682
# processing row 683
# processing row 684
# processing row 685
# processing row 686
# processing row 687
# processing row 688
# processing row 689
# processing row 690
# processing row 691
# processing row 692
# processing row 693
# processing row 694
# processing row 695
# processing row 696
# processing row 697
# processing row 698
# processing row 699
# processing row 700
# processing row 701
# processing row 702
# processing row 703
# processing row 704
# processing row 705
# processing row 706
# processing row 707
# processing row 708
# processing row 709
# processing row 710
# processing row 711
# processing row 712
# processing row 713
# processing row 714
# processing row 715
# processing row 716
# processing row 717
# processing row 718
# processing row 762
# processing row 763
# processing row 764
# processing row 765
# processing row 766
# processing row 767
# processing row 768
# processing row 769
# processing row 770
# processing row 771
# processing row 772
# processing row 773
# processing row 774
# processing row 775
# processing row 776
# processing row 777
# processing row 778
# processing row 779
# processing row 780
# processing row 781
# processing row 782
# processing row 783
# processing row 784
# processing row 785
# processing row 786
# processing row 787
# processing row 788
# processing row 789
# processing row 790
# processing row 791
# processing row 792
# processing row 793
# processing row 794
# processing row 795
# processing row 796
# processing row 797
# processing row 798
# processing row 799
# processing row 800
# processing row 801
# processing row 802
# processing row 803
# processing row 804
# processing row 848
# processing row 849
# processing row 850
# processing row 851
# processing row 852
# processing row 853
# processing row 854
# processing row 855
# processing row 856
# processing row 857
# processing row 858
# processing row 859
# processing row 860
# processing row 861
# processing row 862
# processing row 863
# processing row 864
# processing row 865
# processing row 866
# processing row 867
# processing row 868
# processing row 869
# processing row 870
# processing row 871
# processing row 872
# processing row 873
# processing row 874
# processing row 875
# processing row 904
# processing row 905
# processing row 906
# processing row 907
# processing row 908
# processing row 909
# processing row 910
# processing row 911
# processing row 912
# processing row 913
# processing row 914
# processing row 915
# processing row 916
# processing row 917
# processing row 918
# processing row 919
# processing row 920
# processing row 921
# processing row 922
# processing row 923
# processing row 924
# processing row 925
# processing row 926
# processing row 927
# processing row 928
# processing row 929
# processing row 930
# processing row 931
# processing row 932
# processing row 933
# processing row 934
# processing row 935
# processing row 936
# processing row 937
# processing row 938
# processing row 939
# processing row 940
# processing row 941
# processing row 942
# processing row 943
# processing row 944
# processing row 945
# processing row 946
# processing row 947
# processing row 948
# processing row 949
# processing row 950
# processing row 951
# processing row 952
# processing row 953
# processing row 954
# processing row 955
# processing row 956
# processing row 957
# processing row 958
# processing row 959
# processing row 960
# processing row 961
# processing row 962
# processing row 963
# processing row 964
# processing row 965
# processing row 966
# processing row 967
# processing row 968
# processing row 969
# processing row 970
# processing row 971
# processing row 972
# processing row 973
# processing row 974
# processing row 975
# processing row 976
# processing row 1048
# processing row 1049
# processing row 1050
# processing row 1051
# processing row 1052
# processing row 1053
# processing row 1054
# processing row 1055
# processing row 1056
# processing row 1057
# processing row 1058
# processing row 1059
# processing row 1060
# processing row 1061
# processing row 1062
# processing row 1063
# processing row 1064
# processing row 1065
# processing row 1066
# processing row 1067
# processing row 1068
# processing row 1069
# processing row 1070
# processing row 1071
# processing row 1072
# processing row 1073
# processing row 1074
# processing row 1075
# processing row 1076
# processing row 1077
# processing row 1078
# processing row 1079
# processing row 1080
# processing row 1081
# processing row 1082
# processing row 1083
# processing row 1084
# processing row 1085
# processing row 1086
# processing row 1126
# processing row 1127
# processing row 1128
# processing row 1129
# processing row 1130
# processing row 1131
# processing row 1132
# processing row 1133
# processing row 1134
# processing row 1135
# processing row 1136
# processing row 1137
# processing row 1138
# processing row 1139
# processing row 1140
# processing row 1141
# processing row 1142
# processing row 1143
# processing row 1144
# processing row 1145
# processing row 1146
# processing row 1147
# processing row 1148
# processing row 1149
# processing row 1150
# processing row 1151
# processing row 1152
# processing row 1153
# processing row 1154
# processing row 1155
# processing row 1156
# processing row 1157
# processing row 1158
# processing row 1159
# processing row 1160
# processing row 1161
# processing row 1162
# processing row 1163
# processing row 1164
# processing row 1165
# processing row 1166
# processing row 1167
# processing row 1168
# processing row 1169
# processing row 1170
# processing row 1171
# processing row 1172
# processing row 1173
# processing row 1174
# processing row 1175
# processing row 1176
# processing row 1228
# processing row 1229
# processing row 1230
# processing row 1231
# processing row 1232
# processing row 1233
# processing row 1234
# processing row 1235
# processing row 1236
# processing row 1237
# processing row 1238
# processing row 1239
# processing row 1240
# processing row 1241
# processing row 1242
# processing row 1243
# processing row 1244
# processing row 1245
# processing row 1246
# processing row 1247
# processing row 1248
# processing row 1249
# processing row 1250
# processing row 1251
# processing row 1252
# processing row 1253
# processing row 1254
# processing row 1255
# processing row 1256
# processing row 1257
# processing row 1258
# processing row 1259
# processing row 1260
# processing row 1261
# processing row 1262
# processing row 1263
# processing row 1264
# processing row 1265
# processing row 1266
# processing row 1267
# processing row 1268
# processing row 1269
# processing row 1270
# processing row 1271
# processing row 1317
# processing row 1318
# processing row 1319
# processing row 1320
# processing row 1321
# processing row 1322
# processing row 1323
# processing row 1324
# processing row 1325
# processing row 1326
# processing row 1327
# processing row 1328
# processing row 1329
# processing row 1330
# processing row 1331
# processing row 1332
# processing row 1333
# processing row 1334
# processing row 1335
# processing row 1336
# processing row 1337
# processing row 1338
# processing row 1339
# processing row 1340
# processing row 1341
# processing row 1342
# processing row 1343
# processing row 1344
# processing row 1345
# processing row 1346
# processing row 1347
# processing row 1348
# processing row 1349
# processing row 1350
# processing row 1351
# processing row 1352
# processing row 1353
# processing row 1354
# processing row 1355
# processing row 1356
# processing row 1357
# processing row 1399
# processing row 1400
# processing row 1401
# processing row 1402
# processing row 1403
# processing row 1404
# processing row 1405
# processing row 1406
# processing row 1407
# processing row 1408
# processing row 1409
# processing row 1410
# processing row 1411
# processing row 1412
# processing row 1413
# processing row 1414
# processing row 1415
# processing row 1416
# processing row 1417
# processing row 1418
# processing row 1419
# processing row 1420
# processing row 1421
# processing row 1422
# processing row 1423
# processing row 1424
# processing row 1425
# processing row 1426
# processing row 1427
# processing row 1428
# processing row 1429
# processing row 1430
# processing row 1431
# processing row 1432
# processing row 1433
# processing row 1434
# processing row 1435
# processing row 1436
# processing row 1437
# processing row 1438
# processing row 1439
# processing row 1440
# processing row 1441
# processing row 1442
# processing row 1443
# processing row 1444
# processing row 1445
# processing row 1446
# processing row 1447
# processing row 1448
# processing row 1449
# processing row 1450
# processing row 1451
# processing row 1452
# processing row 1453
# processing row 1454
# processing row 1455
# processing row 1456
# processing row 1457
# processing row 1458
# processing row 1459
# processing row 1460
# processing row 1461
# processing row 1462
# processing row 1463
# processing row 1464
# processing row 1465
# processing row 1466
# processing row 1467
# processing row 1468
# processing row 1469
# processing row 1470
# processing row 1471
# processing row 1545
# processing row 1546
# processing row 1547
# processing row 1548
# processing row 1549
# processing row 1550
# processing row 1551
# processing row 1552
# processing row 1553
# processing row 1554
# processing row 1555
# processing row 1556
# processing row 1557
# processing row 1558
# processing row 1559
# processing row 1560
# processing row 1561
# processing row 1562
# processing row 1563
# processing row 1564
# processing row 1565
# processing row 1566
# processing row 1567
# processing row 1568
# processing row 1569
# processing row 1570
# processing row 1571
# processing row 1572
# processing row 1573
# processing row 1574
# processing row 1575
# processing row 1576
# processing row 1577
# processing row 1578
# processing row 1579
# processing row 1580
# processing row 1581
# processing row 1582
# processing row 1583
# processing row 1584
# processing row 1585
# processing row 1586
# processing row 1587
# processing row 1631
# processing row 1632
# processing row 1633
# processing row 1634
# processing row 1635
# processing row 1636
# processing row 1637
# processing row 1638
# processing row 1639
# processing row 1640
# processing row 1641
# processing row 1642
# processing row 1643
# processing row 1644
# processing row 1645
# processing row 1646
# processing row 1647
# processing row 1648
# processing row 1649
# processing row 1650
# processing row 1651
# processing row 1652
# processing row 1653
# processing row 1654
# processing row 1655
# processing row 1656
# processing row 1657
# processing row 1658
# processing row 1659
# processing row 1660
# processing row 1661
# processing row 1662
# processing row 1663
# processing row 1664
# processing row 1665
# processing row 1666
# processing row 1667
# processing row 1668
# processing row 1669
# processing row 1670
# processing row 1671
# processing row 1672
# processing row 1673
# processing row 1674
# processing row 1675
# processing row 1676
# processing row 1677
# processing row 1678
# processing row 1679
# processing row 1680
# processing row 1681
# processing row 1682
# processing row 1683
# processing row 1684
# processing row 1685
# processing row 1686
# processing row 1687
# processing row 1688
# processing row 1689
# processing row 1690
# processing row 1691
# processing row 1692
# processing row 1693
# processing row 1694
# processing row 1695
# processing row 1696
# processing row 1697
# processing row 1698
# processing row 1699
# processing row 1700
# processing row 1701
# processing row 1702
# processing row 1703
# processing row 1704
# processing row 1705
# processing row 1706
# processing row 1707
# processing row 1708
# processing row 1709
# processing row 1710
# processing row 1711
# processing row 1712
# processing row 1713
# processing row 1714
# processing row 1715
# processing row 1716
# processing row 1717
# processing row 1805
# processing row 1806
# processing row 1807
# processing row 1808
# processing row 1809
# processing row 1810
# processing row 1811
# processing row 1812
# processing row 1813
# processing row 1814
# processing row 1815
# processing row 1816
# processing row 1817
# processing row 1818
# processing row 1819
# processing row 1820
# processing row 1821
# processing row 1822
# processing row 1823
# processing row 1824
# processing row 1825
# processing row 1826
# processing row 1827
# processing row 1828
# processing row 1829
# processing row 1830
# processing row 1831
# processing row 1832
# processing row 1833
# processing row 1834
# processing row 1835
# processing row 1836
# processing row 1837
# processing row 1838
# processing row 1839
# processing row 1840
# processing row 1841
# processing row 1842
# processing row 1843
# processing row 1844
# processing row 1845
# processing row 1846
# processing row 1847
# processing row 1848
# processing row 1849
# processing row 1850
# processing row 1851
# processing row 1852
# processing row 1853
# processing row 1854
# processing row 1855
# processing row 1856
# processing row 1857
# processing row 1858
# processing row 1859
# processing row 1860
# processing row 1861
# processing row 1862
# processing row 1863
# processing row 1864
# processing row 1865
# processing row 1866
# processing row 1867
# processing row 1868
# processing row 1869
# processing row 1870
# processing row 1871
# processing row 1872
# processing row 1873
# processing row 1874
# processing row 1875
# processing row 1876
# processing row 1877
# processing row 1878
# processing row 1879
# processing row 1955
# processing row 1956
# processing row 1957
# processing row 1958
# processing row 1959
# processing row 1960
# processing row 1961
# processing row 1962
# processing row 1963
# processing row 1964
# processing row 1965
# processing row 1966
# processing row 1967
# processing row 1968
# processing row 1969
# processing row 1970
# processing row 1971
# processing row 1972
# processing row 1973
# processing row 1974
# processing row 1975
# processing row 1976
# processing row 1977
# processing row 1978
# processing row 1979
# processing row 1980
# processing row 1981
# processing row 1982
# processing row 1983
# processing row 1984
# processing row 1985
# processing row 1986
# processing row 1987
# processing row 1988
# processing row 1989
# processing row 1990
# processing row 1991
# processing row 1992
# processing row 1993
# processing row 1994
# processing row 1995
# processing row 1996
# processing row 1997
# processing row 1998
# processing row 1999
# processing row 2000
# processing row 2001
# processing row 2002
# processing row 2003
# processing row 2004
# processing row 2005
# processing row 2006
# processing row 2007
# processing row 2008
# processing row 2009
# processing row 2010
# processing row 2011
# processing row 2012
# processing row 2013
# processing row 2014
# processing row 2015
# processing row 2016
# processing row 2017
# processing row 2018
# processing row 2019
# processing row 2020
# processing row 2021
# processing row 2022
# processing row 2023
# processing row 2024
# processing row 2025
# processing row 2026
# processing row 2027
# processing row 2028
# processing row 2029
# processing row 2030
# processing row 2031
# processing row 2032
# processing row 2033
# processing row 2034
# processing row 2035
# processing row 2036
# processing row 2037
# processing row 2038
# processing row 2039
# processing row 2040
# processing row 2041
# processing row 2042
# processing row 2131
# processing row 2132
# processing row 2133
# processing row 2134
# processing row 2135
# processing row 2136
# processing row 2137
# processing row 2138
# processing row 2139
# processing row 2140
# processing row 2141
# processing row 2142
# processing row 2143
# processing row 2144
# processing row 2145
# processing row 2146
# processing row 2147
# processing row 2148
# processing row 2149
# processing row 2150
# processing row 2151
# processing row 2152
# processing row 2153
# processing row 2154
# processing row 2155
# processing row 2156
# processing row 2157
# processing row 2158
# processing row 2159
# processing row 2160
# processing row 2161
# processing row 2162
# processing row 2163
# processing row 2164
# processing row 2165
# processing row 2166
# processing row 2167
# processing row 2168
# processing row 2169
# processing row 2170
# processing row 2171
# processing row 2213
# processing row 2214
# processing row 2215
# processing row 2216
# processing row 2217
# processing row 2218
# processing row 2219
# processing row 2220
# processing row 2221
# processing row 2222
# processing row 2223
# processing row 2224
# processing row 2225
# processing row 2226
# processing row 2227
# processing row 2228
# processing row 2229
# processing row 2230
# processing row 2231
# processing row 2232
# processing row 2233
# processing row 2234
# processing row 2235
# processing row 2236
# processing row 2261
# processing row 2262
# processing row 2263
# processing row 2264
# processing row 2265
# processing row 2266
# processing row 2267
# processing row 2268
# processing row 2269
# processing row 2270
# processing row 2271
# processing row 2272
# processing row 2273
# processing row 2274
# processing row 2275
# processing row 2276
# processing row 2277
# processing row 2278
# processing row 2279
# processing row 2280
# processing row 2281
# processing row 2282
# processing row 2283
# processing row 2307
# processing row 2308
# processing row 2309
# processing row 2310
# processing row 2311
# processing row 2312
# processing row 2313
# processing row 2314
# processing row 2315
# processing row 2316
# processing row 2317
# processing row 2318
# processing row 2319
# processing row 2320
# processing row 2321
# processing row 2322
# processing row 2323
# processing row 2324
# processing row 2325
# processing row 2326
# processing row 2327
# processing row 2328
# processing row 2329
# processing row 2330
# processing row 2331
# processing row 2332
# processing row 2333
# processing row 2334
# processing row 2335
# processing row 2336
# processing row 2337
# processing row 2338
# processing row 2339
# processing row 2340
# processing row 2341
# processing row 2342
# processing row 2343
# processing row 2344
# processing row 2345
# processing row 2346
# processing row 2347
# processing row 2348
# processing row 2349
# processing row 2393
# processing row 2394
# processing row 2395
# processing row 2396
# processing row 2397
# processing row 2398
# processing row 2399
# processing row 2400
# processing row 2401
# processing row 2402
# processing row 2403
# processing row 2404
# processing row 2405
# processing row 2406
# processing row 2407
# processing row 2408
# processing row 2409
# processing row 2410
# processing row 2411
# processing row 2412
# processing row 2413
# processing row 2414
# processing row 2415
# processing row 2416
# processing row 2417
# processing row 2418
# processing row 2419
# processing row 2420
# processing row 2421
# processing row 2422
# processing row 2423
# processing row 2424
# processing row 2425
# processing row 2426
# processing row 2427
# processing row 2428
# processing row 2429
# processing row 2430
# processing row 2431
# processing row 2432
# processing row 2433
# processing row 2434
# processing row 2435
# processing row 2479
# processing row 2480
# processing row 2481
# processing row 2482
# processing row 2483
# processing row 2484
# processing row 2485
# processing row 2486
# processing row 2487
# processing row 2488
# processing row 2489
# processing row 2490
# processing row 2491
# processing row 2492
# processing row 2493
# processing row 2494
# processing row 2495
# processing row 2496
# processing row 2497
# processing row 2498
# processing row 2499
# processing row 2500
# processing row 2501
# processing row 2502
# processing row 2503
# processing row 2504
# processing row 2505
# processing row 2506
# processing row 2535
# processing row 2536
# processing row 2537
# processing row 2538
# processing row 2539
# processing row 2540
# processing row 2541
# processing row 2542
# processing row 2543
# processing row 2544
# processing row 2545
# processing row 2546
# processing row 2547
# processing row 2548
# processing row 2549
# processing row 2550
# processing row 2551
# processing row 2552
# processing row 2553
# processing row 2554
# processing row 2555
# processing row 2556
# processing row 2557
# processing row 2558
# processing row 2559
# processing row 2560
# processing row 2561
# processing row 2562
# processing row 2563
# processing row 2564
# processing row 2565
# processing row 2566
# processing row 2567
# processing row 2568
# processing row 2569
# processing row 2570
# processing row 2571
# processing row 2572
# processing row 2573
# processing row 2574
# processing row 2575
# processing row 2576
# processing row 2577
# processing row 2578
# processing row 2579
# processing row 2580
# processing row 2581
# processing row 2582
# processing row 2583
# processing row 2584
# processing row 2585
# processing row 2586
# processing row 2587
# processing row 2588
# processing row 2589
# processing row 2590
# processing row 2591
# processing row 2592
# processing row 2593
# processing row 2594
# processing row 2595
# processing row 2596
# processing row 2597
# processing row 2598
# processing row 2599
# processing row 2600
# processing row 2601
# processing row 2602
# processing row 2603
# processing row 2604
# processing row 2605
# processing row 2606
# processing row 2607
# processing row 2679
# processing row 2680
# processing row 2681
# processing row 2682
# processing row 2683
# processing row 2684
# processing row 2685
# processing row 2686
# processing row 2687
# processing row 2688
# processing row 2689
# processing row 2690
# processing row 2691
# processing row 2692
# processing row 2693
# processing row 2694
# processing row 2695
# processing row 2696
# processing row 2697
# processing row 2698
# processing row 2699
# processing row 2700
# processing row 2701
# processing row 2702
# processing row 2703
# processing row 2704
# processing row 2705
# processing row 2706
# processing row 2707
# processing row 2708
# processing row 2709
# processing row 2710
# processing row 2711
# processing row 2712
# processing row 2713
# processing row 2714
# processing row 2715
# processing row 2716
# processing row 2717
# processing row 2757
# processing row 2758
# processing row 2759
# processing row 2760
# processing row 2761
# processing row 2762
# processing row 2763
# processing row 2764
# processing row 2765
# processing row 2766
# processing row 2767
# processing row 2768
# processing row 2769
# processing row 2770
# processing row 2771
# processing row 2772
# processing row 2773
# processing row 2774
# processing row 2775
# processing row 2776
# processing row 2777
# processing row 2778
# processing row 2779
# processing row 2780
# processing row 2781
# processing row 2782
# processing row 2783
# processing row 2784
# processing row 2785
# processing row 2786
# processing row 2787
# processing row 2788
# processing row 2789
# processing row 2790
# processing row 2791
# processing row 2792
# processing row 2793
# processing row 2794
# processing row 2795
# processing row 2796
# processing row 2797
# processing row 2798
# processing row 2799
# processing row 2800
# processing row 2801
# processing row 2802
# processing row 2803
# processing row 2804
# processing row 2805
# processing row 2806
# processing row 2807
# processing row 2859
# processing row 2860
# processing row 2861
# processing row 2862
# processing row 2863
# processing row 2864
# processing row 2865
# processing row 2866
# processing row 2867
# processing row 2868
# processing row 2869
# processing row 2870
# processing row 2871
# processing row 2872
# processing row 2873
# processing row 2874
# processing row 2875
# processing row 2876
# processing row 2877
# processing row 2878
# processing row 2879
# processing row 2880
# processing row 2881
# processing row 2882
# processing row 2883
# processing row 2884
# processing row 2885
# processing row 2886
# processing row 2887
# processing row 2888
# processing row 2889
# processing row 2890
# processing row 2891
# processing row 2892
# processing row 2893
# processing row 2894
# processing row 2895
# processing row 2896
# processing row 2897
# processing row 2898
# processing row 2899
# processing row 2900
# processing row 2901
# processing row 2902
# processing row 2948
# processing row 2949
# processing row 2950
# processing row 2951
# processing row 2952
# processing row 2953
# processing row 2954
# processing row 2955
# processing row 2956
# processing row 2957
# processing row 2958
# processing row 2959
# processing row 2960
# processing row 2961
# processing row 2962
# processing row 2963
# processing row 2964
# processing row 2965
# processing row 2966
# processing row 2967
# processing row 2968
# processing row 2969
# processing row 2970
# processing row 2971
# processing row 2972
# processing row 2973
# processing row 2974
# processing row 2975
# processing row 2976
# processing row 2977
# processing row 2978
# processing row 2979
# processing row 2980
# processing row 2981
# processing row 2982
# processing row 2983
# processing row 2984
# processing row 2985
# processing row 2986
# processing row 2987
# processing row 2988
# processing row 3030
# processing row 3031
# processing row 3032
# processing row 3033
# processing row 3034
# processing row 3035
# processing row 3036
# processing row 3037
# processing row 3038
# processing row 3039
# processing row 3040
# processing row 3041
# processing row 3042
# processing row 3043
# processing row 3044
# processing row 3045
# processing row 3046
# processing row 3047
# processing row 3048
# processing row 3049
# processing row 3050
# processing row 3051
# processing row 3052
# processing row 3053
# processing row 3054
# processing row 3055
# processing row 3056
# processing row 3057
# processing row 3058
# processing row 3059
# processing row 3060
# processing row 3061
# processing row 3062
# processing row 3063
# processing row 3064
# processing row 3065
# processing row 3066
# processing row 3067
# processing row 3068
# processing row 3069
# processing row 3070
# processing row 3071
# processing row 3072
# processing row 3073
# processing row 3074
# processing row 3075
# processing row 3076
# processing row 3077
# processing row 3078
# processing row 3079
# processing row 3080
# processing row 3081
# processing row 3082
# processing row 3083
# processing row 3084
# processing row 3085
# processing row 3086
# processing row 3087
# processing row 3088
# processing row 3089
# processing row 3090
# processing row 3091
# processing row 3092
# processing row 3093
# processing row 3094
# processing row 3095
# processing row 3096
# processing row 3097
# processing row 3098
# processing row 3099
# processing row 3100
# processing row 3101
# processing row 3102
# processing row 3176
# processing row 3177
# processing row 3178
# processing row 3179
# processing row 3180
# processing row 3181
# processing row 3182
# processing row 3183
# processing row 3184
# processing row 3185
# processing row 3186
# processing row 3187
# processing row 3188
# processing row 3189
# processing row 3190
# processing row 3191
# processing row 3192
# processing row 3193
# processing row 3194
# processing row 3195
# processing row 3196
# processing row 3197
# processing row 3198
# processing row 3199
# processing row 3200
# processing row 3201
# processing row 3202
# processing row 3203
# processing row 3204
# processing row 3205
# processing row 3206
# processing row 3207
# processing row 3208
# processing row 3209
# processing row 3210
# processing row 3211
# processing row 3212
# processing row 3213
# processing row 3214
# processing row 3215
# processing row 3216
# processing row 3217
# processing row 3218

# %% [markdown]
# <h3>Testing Alternate Implementations</h3> <a name="2"></a>

# %%
def rank_del_matches(a, data):
  # Compares row a in data to other rows from the same project ranking similarity.
  # If a duplicates some other row, returns the place of that row in the ranking. If not returns NaN.
  # This comparison is solely based on deleted line similarity.

  # Loop through each row. Take measurements for other rows from same project
  similarities = []
  lista = code_change_similarity.find_del_lines(data.loc[a, 'Diff_content'])
  project = data.loc[a, 'Project']
  for b in range(data.shape[0]):
    # Only process rows in the same project besides row a
    if (not a == b) and (project == data.loc[b, 'Project']):
      # Stores a tuple to similarities: (row, degree of similarity)
      listb = code_change_similarity.find_del_lines(data.loc[b, 'Diff_content'])
      similarities.append( (b, code_change_similarity.del_sim(lista, listb)) )

  # Sort the produced list of tuples
  similarities.sort(key = lambda x: x[1], reverse=True)
  
  # Find rank of matching entry in list
  id = data.loc[a, 'Pull_id']
  for i in range(len(similarities)):
    if id == data.loc[similarities[i][0], 'Duplicates']:
      # print(f'{a} matches {similarities[i][0]} in possition {i}') # for debugging
      return i
  
  # No match found in similarities list
  return np.nan



def rank_file_matches(a, data):
  # Compares row a in data to other rows from the same project ranking similarity.
  # If a duplicates some other row, returns the place of that row in the ranking. If not returns NaN.
  # This comparison is solely based on file path similarity.

  # Loop through each row. Take measurements for other rows from same project
  similarities = []
  a_files = data.loc[a, 'Files']
  project = data.loc[a, 'Project']
  for b in range(data.shape[0]):
    # Only process rows in the same project besides row a
    if (not a == b) and (project == data.loc[b, 'Project']):
      # Stores a tuple to similarities: (row, degree of similarity)
      b_files = data.loc[b, 'Files']
      # Must ensure that both are actually strings (they won't be if one is empty)
      if isinstance(a_files, str) and isinstance(b_files, str):
        similarities.append( (b, file_path_similarity.check_path_sim(a_files, b_files)) )
      else:
        similarities.append( (b, 0) )

  # Sort the produced list of tuples
  similarities.sort(key = lambda x: x[1], reverse=True)
  
  # Find rank of matching entry in list
  id = data.loc[a, 'Pull_id']
  for i in range(len(similarities)):
    if id == data.loc[similarities[i][0], 'Duplicates']:
      # print(f'{a} matches {similarities[i][0]} in possition {i}') # for debugging
      return i
  
  # No match found in similarities list
  return np.nan

# %%
processed_dataset_b = dataset.copy()
processed_dataset_b.insert(9, 'Match_Rank_File', np.nan)

for n in range(processed_dataset_b.shape[0]):
  # Only process rows if it has a duplicate (otherwise the search is a waste)
  if not processed_dataset_b.loc[n, 'Duplicates'] == 0:
    print(f'processing row {n}')
    # Stores the match rank to Match_Rank_File
    processed_dataset_b.loc[n, 'Match_Rank_File'] = rank_file_matches(n, processed_dataset_b)

processed_dataset_b.to_excel('/content/drive/MyDrive/SEDS/PullRequeset_processed_alt.xlsx')
# Out:
# processing row 0
# processing row 1
# processing row 2
# processing row 3
# processing row 4
# processing row 5
# processing row 6
# processing row 7
# processing row 8
# processing row 9
# processing row 10
# processing row 11
# processing row 12
# processing row 13
# processing row 14
# processing row 15
# processing row 16
# processing row 17
# processing row 18
# processing row 19
# processing row 20
# processing row 21
# processing row 22
# processing row 23
# processing row 24
# processing row 25
# processing row 26
# processing row 27
# processing row 28
# processing row 29
# processing row 30
# processing row 31
# processing row 32
# processing row 33
# processing row 34
# processing row 35
# processing row 36
# processing row 37
# processing row 38
# processing row 39
# processing row 40
# processing row 41
# processing row 42
# processing row 43
# processing row 44
# processing row 45
# processing row 46
# processing row 47
# processing row 48
# processing row 49
# processing row 50
# processing row 51
# processing row 52
# processing row 53
# processing row 54
# processing row 55
# processing row 56
# processing row 57
# processing row 58
# processing row 59
# processing row 60
# processing row 61
# processing row 62
# processing row 63
# processing row 64
# processing row 65
# processing row 66
# processing row 67
# processing row 68
# processing row 69
# processing row 70
# processing row 71
# processing row 72
# processing row 73
# processing row 74
# processing row 75
# processing row 76
# processing row 77
# processing row 78
# processing row 79
# processing row 80
# processing row 81
# processing row 82
# processing row 83
# processing row 84
# processing row 85
# processing row 86
# processing row 174
# processing row 175
# processing row 176
# processing row 177
# processing row 178
# processing row 179
# processing row 180
# processing row 181
# processing row 182
# processing row 183
# processing row 184
# processing row 185
# processing row 186
# processing row 187
# processing row 188
# processing row 189
# processing row 190
# processing row 191
# processing row 192
# processing row 193
# processing row 194
# processing row 195
# processing row 196
# processing row 197
# processing row 198
# processing row 199
# processing row 200
# processing row 201
# processing row 202
# processing row 203
# processing row 204
# processing row 205
# processing row 206
# processing row 207
# processing row 208
# processing row 209
# processing row 210
# processing row 211
# processing row 212
# processing row 213
# processing row 214
# processing row 215
# processing row 216
# processing row 217
# processing row 218
# processing row 219
# processing row 220
# processing row 221
# processing row 222
# processing row 223
# processing row 224
# processing row 225
# processing row 226
# processing row 227
# processing row 228
# processing row 229
# processing row 230
# processing row 231
# processing row 232
# processing row 233
# processing row 234
# processing row 235
# processing row 236
# processing row 237
# processing row 238
# processing row 239
# processing row 240
# processing row 241
# processing row 242
# processing row 243
# processing row 244
# processing row 245
# processing row 246
# processing row 247
# processing row 248
# processing row 324
# processing row 325
# processing row 326
# processing row 327
# processing row 328
# processing row 329
# processing row 330
# processing row 331
# processing row 332
# processing row 333
# processing row 334
# processing row 335
# processing row 336
# processing row 337
# processing row 338
# processing row 339
# processing row 340
# processing row 341
# processing row 342
# processing row 343
# processing row 344
# processing row 345
# processing row 346
# processing row 347
# processing row 348
# processing row 349
# processing row 350
# processing row 351
# processing row 352
# processing row 353
# processing row 354
# processing row 355
# processing row 356
# processing row 357
# processing row 358
# processing row 359
# processing row 360
# processing row 361
# processing row 362
# processing row 363
# processing row 364
# processing row 365
# processing row 366
# processing row 367
# processing row 368
# processing row 369
# processing row 370
# processing row 371
# processing row 372
# processing row 373
# processing row 374
# processing row 375
# processing row 376
# processing row 377
# processing row 378
# processing row 379
# processing row 380
# processing row 381
# processing row 382
# processing row 383
# processing row 384
# processing row 385
# processing row 386
# processing row 387
# processing row 388
# processing row 389
# processing row 390
# processing row 391
# processing row 392
# processing row 393
# processing row 394
# processing row 395
# processing row 396
# processing row 397
# processing row 398
# processing row 399
# processing row 400
# processing row 401
# processing row 402
# processing row 403
# processing row 404
# processing row 405
# processing row 406
# processing row 407
# processing row 408
# processing row 409
# processing row 410
# processing row 411
# processing row 500
# processing row 501
# processing row 502
# processing row 503
# processing row 504
# processing row 505
# processing row 506
# processing row 507
# processing row 508
# processing row 509
# processing row 510
# processing row 511
# processing row 512
# processing row 513
# processing row 514
# processing row 515
# processing row 516
# processing row 517
# processing row 518
# processing row 519
# processing row 520
# processing row 521
# processing row 522
# processing row 523
# processing row 524
# processing row 525
# processing row 526
# processing row 527
# processing row 528
# processing row 529
# processing row 530
# processing row 531
# processing row 532
# processing row 533
# processing row 534
# processing row 535
# processing row 536
# processing row 537
# processing row 538
# processing row 539
# processing row 540
# processing row 582
# processing row 583
# processing row 584
# processing row 585
# processing row 586
# processing row 587
# processing row 588
# processing row 589
# processing row 590
# processing row 591
# processing row 592
# processing row 593
# processing row 594
# processing row 595
# processing row 596
# processing row 597
# processing row 598
# processing row 599
# processing row 600
# processing row 601
# processing row 602
# processing row 603
# processing row 604
# processing row 605
# processing row 630
# processing row 631
# processing row 632
# processing row 633
# processing row 634
# processing row 635
# processing row 636
# processing row 637
# processing row 638
# processing row 639
# processing row 640
# processing row 641
# processing row 642
# processing row 643
# processing row 644
# processing row 645
# processing row 646
# processing row 647
# processing row 648
# processing row 649
# processing row 650
# processing row 651
# processing row 652
# processing row 676
# processing row 677
# processing row 678
# processing row 679
# processing row 680
# processing row 681
# processing row 682
# processing row 683
# processing row 684
# processing row 685
# processing row 686
# processing row 687
# processing row 688
# processing row 689
# processing row 690
# processing row 691
# processing row 692
# processing row 693
# processing row 694
# processing row 695
# processing row 696
# processing row 697
# processing row 698
# processing row 699
# processing row 700
# processing row 701
# processing row 702
# processing row 703
# processing row 704
# processing row 705
# processing row 706
# processing row 707
# processing row 708
# processing row 709
# processing row 710
# processing row 711
# processing row 712
# processing row 713
# processing row 714
# processing row 715
# processing row 716
# processing row 717
# processing row 718
# processing row 762
# processing row 763
# processing row 764
# processing row 765
# processing row 766
# processing row 767
# processing row 768
# processing row 769
# processing row 770
# processing row 771
# processing row 772
# processing row 773
# processing row 774
# processing row 775
# processing row 776
# processing row 777
# processing row 778
# processing row 779
# processing row 780
# processing row 781
# processing row 782
# processing row 783
# processing row 784
# processing row 785
# processing row 786
# processing row 787
# processing row 788
# processing row 789
# processing row 790
# processing row 791
# processing row 792
# processing row 793
# processing row 794
# processing row 795
# processing row 796
# processing row 797
# processing row 798
# processing row 799
# processing row 800
# processing row 801
# processing row 802
# processing row 803
# processing row 804
# processing row 848
# processing row 849
# processing row 850
# processing row 851
# processing row 852
# processing row 853
# processing row 854
# processing row 855
# processing row 856
# processing row 857
# processing row 858
# processing row 859
# processing row 860
# processing row 861
# processing row 862
# processing row 863
# processing row 864
# processing row 865
# processing row 866
# processing row 867
# processing row 868
# processing row 869
# processing row 870
# processing row 871
# processing row 872
# processing row 873
# processing row 874
# processing row 875
# processing row 904
# processing row 905
# processing row 906
# processing row 907
# processing row 908
# processing row 909
# processing row 910
# processing row 911
# processing row 912
# processing row 913
# processing row 914
# processing row 915
# processing row 916
# processing row 917
# processing row 918
# processing row 919
# processing row 920
# processing row 921
# processing row 922
# processing row 923
# processing row 924
# processing row 925
# processing row 926
# processing row 927
# processing row 928
# processing row 929
# processing row 930
# processing row 931
# processing row 932
# processing row 933
# processing row 934
# processing row 935
# processing row 936
# processing row 937
# processing row 938
# processing row 939
# processing row 940
# processing row 941
# processing row 942
# processing row 943
# processing row 944
# processing row 945
# processing row 946
# processing row 947
# processing row 948
# processing row 949
# processing row 950
# processing row 951
# processing row 952
# processing row 953
# processing row 954
# processing row 955
# processing row 956
# processing row 957
# processing row 958
# processing row 959
# processing row 960
# processing row 961
# processing row 962
# processing row 963
# processing row 964
# processing row 965
# processing row 966
# processing row 967
# processing row 968
# processing row 969
# processing row 970
# processing row 971
# processing row 972
# processing row 973
# processing row 974
# processing row 975
# processing row 976
# processing row 1048
# processing row 1049
# processing row 1050
# processing row 1051
# processing row 1052
# processing row 1053
# processing row 1054
# processing row 1055
# processing row 1056
# processing row 1057
# processing row 1058
# processing row 1059
# processing row 1060
# processing row 1061
# processing row 1062
# processing row 1063
# processing row 1064
# processing row 1065
# processing row 1066
# processing row 1067
# processing row 1068
# processing row 1069
# processing row 1070
# processing row 1071
# processing row 1072
# processing row 1073
# processing row 1074
# processing row 1075
# processing row 1076
# processing row 1077
# processing row 1078
# processing row 1079
# processing row 1080
# processing row 1081
# processing row 1082
# processing row 1083
# processing row 1084
# processing row 1085
# processing row 1086
# processing row 1126
# processing row 1127
# processing row 1128
# processing row 1129
# processing row 1130
# processing row 1131
# processing row 1132
# processing row 1133
# processing row 1134
# processing row 1135
# processing row 1136
# processing row 1137
# processing row 1138
# processing row 1139
# processing row 1140
# processing row 1141
# processing row 1142
# processing row 1143
# processing row 1144
# processing row 1145
# processing row 1146
# processing row 1147
# processing row 1148
# processing row 1149
# processing row 1150
# processing row 1151
# processing row 1152
# processing row 1153
# processing row 1154
# processing row 1155
# processing row 1156
# processing row 1157
# processing row 1158
# processing row 1159
# processing row 1160
# processing row 1161
# processing row 1162
# processing row 1163
# processing row 1164
# processing row 1165
# processing row 1166
# processing row 1167
# processing row 1168
# processing row 1169
# processing row 1170
# processing row 1171
# processing row 1172
# processing row 1173
# processing row 1174
# processing row 1175
# processing row 1176
# processing row 1228
# processing row 1229
# processing row 1230
# processing row 1231
# processing row 1232
# processing row 1233
# processing row 1234
# processing row 1235
# processing row 1236
# processing row 1237
# processing row 1238
# processing row 1239
# processing row 1240
# processing row 1241
# processing row 1242
# processing row 1243
# processing row 1244
# processing row 1245
# processing row 1246
# processing row 1247
# processing row 1248
# processing row 1249
# processing row 1250
# processing row 1251
# processing row 1252
# processing row 1253
# processing row 1254
# processing row 1255
# processing row 1256
# processing row 1257
# processing row 1258
# processing row 1259
# processing row 1260
# processing row 1261
# processing row 1262
# processing row 1263
# processing row 1264
# processing row 1265
# processing row 1266
# processing row 1267
# processing row 1268
# processing row 1269
# processing row 1270
# processing row 1271
# processing row 1317
# processing row 1318
# processing row 1319
# processing row 1320
# processing row 1321
# processing row 1322
# processing row 1323
# processing row 1324
# processing row 1325
# processing row 1326
# processing row 1327
# processing row 1328
# processing row 1329
# processing row 1330
# processing row 1331
# processing row 1332
# processing row 1333
# processing row 1334
# processing row 1335
# processing row 1336
# processing row 1337
# processing row 1338
# processing row 1339
# processing row 1340
# processing row 1341
# processing row 1342
# processing row 1343
# processing row 1344
# processing row 1345
# processing row 1346
# processing row 1347
# processing row 1348
# processing row 1349
# processing row 1350
# processing row 1351
# processing row 1352
# processing row 1353
# processing row 1354
# processing row 1355
# processing row 1356
# processing row 1357
# processing row 1399
# processing row 1400
# processing row 1401
# processing row 1402
# processing row 1403
# processing row 1404
# processing row 1405
# processing row 1406
# processing row 1407
# processing row 1408
# processing row 1409
# processing row 1410
# processing row 1411
# processing row 1412
# processing row 1413
# processing row 1414
# processing row 1415
# processing row 1416
# processing row 1417
# processing row 1418
# processing row 1419
# processing row 1420
# processing row 1421
# processing row 1422
# processing row 1423
# processing row 1424
# processing row 1425
# processing row 1426
# processing row 1427
# processing row 1428
# processing row 1429
# processing row 1430
# processing row 1431
# processing row 1432
# processing row 1433
# processing row 1434
# processing row 1435
# processing row 1436
# processing row 1437
# processing row 1438
# processing row 1439
# processing row 1440
# processing row 1441
# processing row 1442
# processing row 1443
# processing row 1444
# processing row 1445
# processing row 1446
# processing row 1447
# processing row 1448
# processing row 1449
# processing row 1450
# processing row 1451
# processing row 1452
# processing row 1453
# processing row 1454
# processing row 1455
# processing row 1456
# processing row 1457
# processing row 1458
# processing row 1459
# processing row 1460
# processing row 1461
# processing row 1462
# processing row 1463
# processing row 1464
# processing row 1465
# processing row 1466
# processing row 1467
# processing row 1468
# processing row 1469
# processing row 1470
# processing row 1471
# processing row 1545
# processing row 1546
# processing row 1547
# processing row 1548
# processing row 1549
# processing row 1550
# processing row 1551
# processing row 1552
# processing row 1553
# processing row 1554
# processing row 1555
# processing row 1556
# processing row 1557
# processing row 1558
# processing row 1559
# processing row 1560
# processing row 1561
# processing row 1562
# processing row 1563
# processing row 1564
# processing row 1565
# processing row 1566
# processing row 1567
# processing row 1568
# processing row 1569
# processing row 1570
# processing row 1571
# processing row 1572
# processing row 1573
# processing row 1574
# processing row 1575
# processing row 1576
# processing row 1577
# processing row 1578
# processing row 1579
# processing row 1580
# processing row 1581
# processing row 1582
# processing row 1583
# processing row 1584
# processing row 1585
# processing row 1586
# processing row 1587
# processing row 1631
# processing row 1632
# processing row 1633
# processing row 1634
# processing row 1635
# processing row 1636
# processing row 1637
# processing row 1638
# processing row 1639
# processing row 1640
# processing row 1641
# processing row 1642
# processing row 1643
# processing row 1644
# processing row 1645
# processing row 1646
# processing row 1647
# processing row 1648
# processing row 1649
# processing row 1650
# processing row 1651
# processing row 1652
# processing row 1653
# processing row 1654
# processing row 1655
# processing row 1656
# processing row 1657
# processing row 1658
# processing row 1659
# processing row 1660
# processing row 1661
# processing row 1662
# processing row 1663
# processing row 1664
# processing row 1665
# processing row 1666
# processing row 1667
# processing row 1668
# processing row 1669
# processing row 1670
# processing row 1671
# processing row 1672
# processing row 1673
# processing row 1674
# processing row 1675
# processing row 1676
# processing row 1677
# processing row 1678
# processing row 1679
# processing row 1680
# processing row 1681
# processing row 1682
# processing row 1683
# processing row 1684
# processing row 1685
# processing row 1686
# processing row 1687
# processing row 1688
# processing row 1689
# processing row 1690
# processing row 1691
# processing row 1692
# processing row 1693
# processing row 1694
# processing row 1695
# processing row 1696
# processing row 1697
# processing row 1698
# processing row 1699
# processing row 1700
# processing row 1701
# processing row 1702
# processing row 1703
# processing row 1704
# processing row 1705
# processing row 1706
# processing row 1707
# processing row 1708
# processing row 1709
# processing row 1710
# processing row 1711
# processing row 1712
# processing row 1713
# processing row 1714
# processing row 1715
# processing row 1716
# processing row 1717
# processing row 1805
# processing row 1806
# processing row 1807
# processing row 1808
# processing row 1809
# processing row 1810
# processing row 1811
# processing row 1812
# processing row 1813
# processing row 1814
# processing row 1815
# processing row 1816
# processing row 1817
# processing row 1818
# processing row 1819
# processing row 1820
# processing row 1821
# processing row 1822
# processing row 1823
# processing row 1824
# processing row 1825
# processing row 1826
# processing row 1827
# processing row 1828
# processing row 1829
# processing row 1830
# processing row 1831
# processing row 1832
# processing row 1833
# processing row 1834
# processing row 1835
# processing row 1836
# processing row 1837
# processing row 1838
# processing row 1839
# processing row 1840
# processing row 1841
# processing row 1842
# processing row 1843
# processing row 1844
# processing row 1845
# processing row 1846
# processing row 1847
# processing row 1848
# processing row 1849
# processing row 1850
# processing row 1851
# processing row 1852
# processing row 1853
# processing row 1854
# processing row 1855
# processing row 1856
# processing row 1857
# processing row 1858
# processing row 1859
# processing row 1860
# processing row 1861
# processing row 1862
# processing row 1863
# processing row 1864
# processing row 1865
# processing row 1866
# processing row 1867
# processing row 1868
# processing row 1869
# processing row 1870
# processing row 1871
# processing row 1872
# processing row 1873
# processing row 1874
# processing row 1875
# processing row 1876
# processing row 1877
# processing row 1878
# processing row 1879
# processing row 1955
# processing row 1956
# processing row 1957
# processing row 1958
# processing row 1959
# processing row 1960
# processing row 1961
# processing row 1962
# processing row 1963
# processing row 1964
# processing row 1965
# processing row 1966
# processing row 1967
# processing row 1968
# processing row 1969
# processing row 1970
# processing row 1971
# processing row 1972
# processing row 1973
# processing row 1974
# processing row 1975
# processing row 1976
# processing row 1977
# processing row 1978
# processing row 1979
# processing row 1980
# processing row 1981
# processing row 1982
# processing row 1983
# processing row 1984
# processing row 1985
# processing row 1986
# processing row 1987
# processing row 1988
# processing row 1989
# processing row 1990
# processing row 1991
# processing row 1992
# processing row 1993
# processing row 1994
# processing row 1995
# processing row 1996
# processing row 1997
# processing row 1998
# processing row 1999
# processing row 2000
# processing row 2001
# processing row 2002
# processing row 2003
# processing row 2004
# processing row 2005
# processing row 2006
# processing row 2007
# processing row 2008
# processing row 2009
# processing row 2010
# processing row 2011
# processing row 2012
# processing row 2013
# processing row 2014
# processing row 2015
# processing row 2016
# processing row 2017
# processing row 2018
# processing row 2019
# processing row 2020
# processing row 2021
# processing row 2022
# processing row 2023
# processing row 2024
# processing row 2025
# processing row 2026
# processing row 2027
# processing row 2028
# processing row 2029
# processing row 2030
# processing row 2031
# processing row 2032
# processing row 2033
# processing row 2034
# processing row 2035
# processing row 2036
# processing row 2037
# processing row 2038
# processing row 2039
# processing row 2040
# processing row 2041
# processing row 2042
# processing row 2131
# processing row 2132
# processing row 2133
# processing row 2134
# processing row 2135
# processing row 2136
# processing row 2137
# processing row 2138
# processing row 2139
# processing row 2140
# processing row 2141
# processing row 2142
# processing row 2143
# processing row 2144
# processing row 2145
# processing row 2146
# processing row 2147
# processing row 2148
# processing row 2149
# processing row 2150
# processing row 2151
# processing row 2152
# processing row 2153
# processing row 2154
# processing row 2155
# processing row 2156
# processing row 2157
# processing row 2158
# processing row 2159
# processing row 2160
# processing row 2161
# processing row 2162
# processing row 2163
# processing row 2164
# processing row 2165
# processing row 2166
# processing row 2167
# processing row 2168
# processing row 2169
# processing row 2170
# processing row 2171
# processing row 2213
# processing row 2214
# processing row 2215
# processing row 2216
# processing row 2217
# processing row 2218
# processing row 2219
# processing row 2220
# processing row 2221
# processing row 2222
# processing row 2223
# processing row 2224
# processing row 2225
# processing row 2226
# processing row 2227
# processing row 2228
# processing row 2229
# processing row 2230
# processing row 2231
# processing row 2232
# processing row 2233
# processing row 2234
# processing row 2235
# processing row 2236
# processing row 2261
# processing row 2262
# processing row 2263
# processing row 2264
# processing row 2265
# processing row 2266
# processing row 2267
# processing row 2268
# processing row 2269
# processing row 2270
# processing row 2271
# processing row 2272
# processing row 2273
# processing row 2274
# processing row 2275
# processing row 2276
# processing row 2277
# processing row 2278
# processing row 2279
# processing row 2280
# processing row 2281
# processing row 2282
# processing row 2283
# processing row 2307
# processing row 2308
# processing row 2309
# processing row 2310
# processing row 2311
# processing row 2312
# processing row 2313
# processing row 2314
# processing row 2315
# processing row 2316
# processing row 2317
# processing row 2318
# processing row 2319
# processing row 2320
# processing row 2321
# processing row 2322
# processing row 2323
# processing row 2324
# processing row 2325
# processing row 2326
# processing row 2327
# processing row 2328
# processing row 2329
# processing row 2330
# processing row 2331
# processing row 2332
# processing row 2333
# processing row 2334
# processing row 2335
# processing row 2336
# processing row 2337
# processing row 2338
# processing row 2339
# processing row 2340
# processing row 2341
# processing row 2342
# processing row 2343
# processing row 2344
# processing row 2345
# processing row 2346
# processing row 2347
# processing row 2348
# processing row 2349
# processing row 2393
# processing row 2394
# processing row 2395
# processing row 2396
# processing row 2397
# processing row 2398
# processing row 2399
# processing row 2400
# processing row 2401
# processing row 2402
# processing row 2403
# processing row 2404
# processing row 2405
# processing row 2406
# processing row 2407
# processing row 2408
# processing row 2409
# processing row 2410
# processing row 2411
# processing row 2412
# processing row 2413
# processing row 2414
# processing row 2415
# processing row 2416
# processing row 2417
# processing row 2418
# processing row 2419
# processing row 2420
# processing row 2421
# processing row 2422
# processing row 2423
# processing row 2424
# processing row 2425
# processing row 2426
# processing row 2427
# processing row 2428
# processing row 2429
# processing row 2430
# processing row 2431
# processing row 2432
# processing row 2433
# processing row 2434
# processing row 2435
# processing row 2479
# processing row 2480
# processing row 2481
# processing row 2482
# processing row 2483
# processing row 2484
# processing row 2485
# processing row 2486
# processing row 2487
# processing row 2488
# processing row 2489
# processing row 2490
# processing row 2491
# processing row 2492
# processing row 2493
# processing row 2494
# processing row 2495
# processing row 2496
# processing row 2497
# processing row 2498
# processing row 2499
# processing row 2500
# processing row 2501
# processing row 2502
# processing row 2503
# processing row 2504
# processing row 2505
# processing row 2506
# processing row 2535
# processing row 2536
# processing row 2537
# processing row 2538
# processing row 2539
# processing row 2540
# processing row 2541
# processing row 2542
# processing row 2543
# processing row 2544
# processing row 2545
# processing row 2546
# processing row 2547
# processing row 2548
# processing row 2549
# processing row 2550
# processing row 2551
# processing row 2552
# processing row 2553
# processing row 2554
# processing row 2555
# processing row 2556
# processing row 2557
# processing row 2558
# processing row 2559
# processing row 2560
# processing row 2561
# processing row 2562
# processing row 2563
# processing row 2564
# processing row 2565
# processing row 2566
# processing row 2567
# processing row 2568
# processing row 2569
# processing row 2570
# processing row 2571
# processing row 2572
# processing row 2573
# processing row 2574
# processing row 2575
# processing row 2576
# processing row 2577
# processing row 2578
# processing row 2579
# processing row 2580
# processing row 2581
# processing row 2582
# processing row 2583
# processing row 2584
# processing row 2585
# processing row 2586
# processing row 2587
# processing row 2588
# processing row 2589
# processing row 2590
# processing row 2591
# processing row 2592
# processing row 2593
# processing row 2594
# processing row 2595
# processing row 2596
# processing row 2597
# processing row 2598
# processing row 2599
# processing row 2600
# processing row 2601
# processing row 2602
# processing row 2603
# processing row 2604
# processing row 2605
# processing row 2606
# processing row 2607
# processing row 2679
# processing row 2680
# processing row 2681
# processing row 2682
# processing row 2683
# processing row 2684
# processing row 2685
# processing row 2686
# processing row 2687
# processing row 2688
# processing row 2689
# processing row 2690
# processing row 2691
# processing row 2692
# processing row 2693
# processing row 2694
# processing row 2695
# processing row 2696
# processing row 2697
# processing row 2698
# processing row 2699
# processing row 2700
# processing row 2701
# processing row 2702
# processing row 2703
# processing row 2704
# processing row 2705
# processing row 2706
# processing row 2707
# processing row 2708
# processing row 2709
# processing row 2710
# processing row 2711
# processing row 2712
# processing row 2713
# processing row 2714
# processing row 2715
# processing row 2716
# processing row 2717
# processing row 2757
# processing row 2758
# processing row 2759
# processing row 2760
# processing row 2761
# processing row 2762
# processing row 2763
# processing row 2764
# processing row 2765
# processing row 2766
# processing row 2767
# processing row 2768
# processing row 2769
# processing row 2770
# processing row 2771
# processing row 2772
# processing row 2773
# processing row 2774
# processing row 2775
# processing row 2776
# processing row 2777
# processing row 2778
# processing row 2779
# processing row 2780
# processing row 2781
# processing row 2782
# processing row 2783
# processing row 2784
# processing row 2785
# processing row 2786
# processing row 2787
# processing row 2788
# processing row 2789
# processing row 2790
# processing row 2791
# processing row 2792
# processing row 2793
# processing row 2794
# processing row 2795
# processing row 2796
# processing row 2797
# processing row 2798
# processing row 2799
# processing row 2800
# processing row 2801
# processing row 2802
# processing row 2803
# processing row 2804
# processing row 2805
# processing row 2806
# processing row 2807
# processing row 2859
# processing row 2860
# processing row 2861
# processing row 2862
# processing row 2863
# processing row 2864
# processing row 2865
# processing row 2866
# processing row 2867
# processing row 2868
# processing row 2869
# processing row 2870
# processing row 2871
# processing row 2872
# processing row 2873
# processing row 2874
# processing row 2875
# processing row 2876
# processing row 2877
# processing row 2878
# processing row 2879
# processing row 2880
# processing row 2881
# processing row 2882
# processing row 2883
# processing row 2884
# processing row 2885
# processing row 2886
# processing row 2887
# processing row 2888
# processing row 2889
# processing row 2890
# processing row 2891
# processing row 2892
# processing row 2893
# processing row 2894
# processing row 2895
# processing row 2896
# processing row 2897
# processing row 2898
# processing row 2899
# processing row 2900
# processing row 2901
# processing row 2902
# processing row 2948
# processing row 2949
# processing row 2950
# processing row 2951
# processing row 2952
# processing row 2953
# processing row 2954
# processing row 2955
# processing row 2956
# processing row 2957
# processing row 2958
# processing row 2959
# processing row 2960
# processing row 2961
# processing row 2962
# processing row 2963
# processing row 2964
# processing row 2965
# processing row 2966
# processing row 2967
# processing row 2968
# processing row 2969
# processing row 2970
# processing row 2971
# processing row 2972
# processing row 2973
# processing row 2974
# processing row 2975
# processing row 2976
# processing row 2977
# processing row 2978
# processing row 2979
# processing row 2980
# processing row 2981
# processing row 2982
# processing row 2983
# processing row 2984
# processing row 2985
# processing row 2986
# processing row 2987
# processing row 2988
# processing row 3030
# processing row 3031
# processing row 3032
# processing row 3033
# processing row 3034
# processing row 3035
# processing row 3036
# processing row 3037
# processing row 3038
# processing row 3039
# processing row 3040
# processing row 3041
# processing row 3042
# processing row 3043
# processing row 3044
# processing row 3045
# processing row 3046
# processing row 3047
# processing row 3048
# processing row 3049
# processing row 3050
# processing row 3051
# processing row 3052
# processing row 3053
# processing row 3054
# processing row 3055
# processing row 3056
# processing row 3057
# processing row 3058
# processing row 3059
# processing row 3060
# processing row 3061
# processing row 3062
# processing row 3063
# processing row 3064
# processing row 3065
# processing row 3066
# processing row 3067
# processing row 3068
# processing row 3069
# processing row 3070
# processing row 3071
# processing row 3072
# processing row 3073
# processing row 3074
# processing row 3075
# processing row 3076
# processing row 3077
# processing row 3078
# processing row 3079
# processing row 3080
# processing row 3081
# processing row 3082
# processing row 3083
# processing row 3084
# processing row 3085
# processing row 3086
# processing row 3087
# processing row 3088
# processing row 3089
# processing row 3090
# processing row 3091
# processing row 3092
# processing row 3093
# processing row 3094
# processing row 3095
# processing row 3096
# processing row 3097
# processing row 3098
# processing row 3099
# processing row 3100
# processing row 3101
# processing row 3102
# processing row 3176
# processing row 3177
# processing row 3178
# processing row 3179
# processing row 3180
# processing row 3181
# processing row 3182
# processing row 3183
# processing row 3184
# processing row 3185
# processing row 3186
# processing row 3187
# processing row 3188
# processing row 3189
# processing row 3190
# processing row 3191
# processing row 3192
# processing row 3193
# processing row 3194
# processing row 3195
# processing row 3196
# processing row 3197
# processing row 3198
# processing row 3199
# processing row 3200
# processing row 3201
# processing row 3202
# processing row 3203
# processing row 3204
# processing row 3205
# processing row 3206
# processing row 3207
# processing row 3208
# processing row 3209
# processing row 3210
# processing row 3211
# processing row 3212
# processing row 3213
# processing row 3214
# processing row 3215
# processing row 3216
# processing row 3217
# processing row 3218
